# %% [markdown]
# ### Import the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the dataset

# %%
df=pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### To check null values

# %% [markdown]
# #### From this we can conclude that no missing values in the dataset

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# #### This function is used to know count,mean,standerd deviation,minimum and maximum values percentile values of each and every feature in the data

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# ### Count of people who are suffering from heart disease

# %%
sns.countplot(x='target',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %% [markdown]
# ##### From the above graph we can conclude that major people are suffering from heart disease
#          1=165 0=138

# %% [markdown]
# ## Feature Analysis
# ### Categorical features

# %% [markdown]
# ### sex feature
#     0->female,1->male

# %%
sns.countplot(x='sex',data=df,hue='target')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# * Here we can observe that number of men who are suffering from heart disease are more than women

# %% [markdown]
# ### FBS(Fasting Blood Pressure)

# %%
sns.countplot(x='fbs',data=df,hue='target')
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='count'>

# %% [markdown]
# * Fasting blood sugar is a diabetes indicator with fbs>120 is considered as a diabetes(True-1).
# * here the true class is lower when compared to false class.
# * If we observe there are more no:of people who has heart disease without diabetes.

# %% [markdown]
# ### Rest ECG

# %%
sns.countplot(x='restecg',data=df,hue='target')
# Out:
# <AxesSubplot:xlabel='restecg', ylabel='count'>

# %% [markdown]
# * An electrocardiogram (ECG) is atest which measures the electrical activity of your heart weather it is working normally or not.
# * An ECG records the heart's rhythm.

# %% [markdown]
#     From the above graph if rest ECG is 1 then person have
#     more chance of having heart disease

# %% [markdown]
# ### Slope (describes patient condition during peak exercise)

# %% [markdown]
#     slope has three values
#         1. flat(1)
#         2. un sloping(0)
#         3. down sloping(2)

# %%
sns.countplot(x='slope',data=df,hue='target')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %% [markdown]
# * From the above graph we can say that the person who has down sloping has higher chance of heart disease.
# * But there is a little chance with  un sloping ,then flat.

# %% [markdown]
# ### CA- Result of fluoroscopy.

# %%
sns.countplot(x='ca',data=df,hue='target')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %%
df['ca'].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
df['ca'].value_counts()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: ca, dtype: int64

# %% [markdown]
# * From the above graph we can see that the persons who is suffering from heart disease have fluroscopy is 0.
# * fluroscopy use to produce x-ray which will makes possible to see internal organs in motions.

# %% [markdown]
# ### Thal (Thallium Test)
# * Thallium test is a nuclear medicine study that shows how well blood flows through your heart muscle while you're exercising or at rest.
# * Test required for patient suffering from pain in chest or difficulty in breathing. There are 4 kinds of values which represent Thallium test.

# %%
sns.countplot(x='thal',data=df,hue='target')
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %% [markdown]
# ### CP(Chest-pain)
#     Represents the severity of chest pain patient is suffering.
#     0-Typical Angina
#     1-Atypical Angina
#     2-Non Anginal
#     3-Asymptomatic

# %%
sns.countplot(x='cp',data=df,hue='target')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %% [markdown]
# * There are four levels of chest pain in given data in which 3 is highest.
# - So,people who has chest pain at 3rd level are very less compared to other levels.
# - There fore ,we can assume that most people will die after 2nd level of chest pain.

# %% [markdown]
# ### Continuous features
#        1.Age
#     2.trestbps
#     3.chol
#     4.old peak
#     5.thalach

# %% [markdown]
# ### age-feature

# %%
sns.boxplot(x='target',y='age',data=df,hue='sex')
# Out:
# <AxesSubplot:xlabel='target', ylabel='age'>

# %% [markdown]
# * from the above graph we can say that persons who doesn't have heart disease has some outliers. i.e;age column has some outliers

# %% [markdown]
# ### trestbps-feature

# %%
sns.boxplot(x='target',y='trestbps',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='trestbps'>

# %% [markdown]
# * if we observe that the median value of blood pressure is same for both who has disease and doesn't have disease.
# * here also have some outliers.

# %% [markdown]
# ### chol-feature

# %%
sns.boxplot(x='target',y='chol',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='chol'>

# %% [markdown]
# * The median of the chol is more for target 0 and there are very high values in target-1

# %% [markdown]
# ### Thalach-feature
#    Thalach refers to heartbeat,i guess this feature plays an important role to decide target.

# %%
sns.boxplot(x='target',y='thalach',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='thalach'>

# %% [markdown]
# * If we observe that people with higher heart beat rate leads to disease.
# * here,the median value of target-1 is greater than target-0.

# %% [markdown]
# ### oldpeak(depression-level)

# %%
sns.boxplot(x='target',y='oldpeak',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='oldpeak'>

# %% [markdown]
# * here there are many outliers,the median value for target-1 is less than target-0.
# * I think, this feature alone won't decide the target variable.

# %% [markdown]
# ## Distribution of the continuous variables

# %% [markdown]
# ### distribution of age

# %%
sns.distplot(df['age'],kde=True)

# %% [markdown]
# * age feature is normally distributed that means there are no outliers

# %% [markdown]
# ### distribution of trestbps

# %%
sns.distplot(df['trestbps'])

# %% [markdown]
# * If we observe that outliers start from 180

# %% [markdown]
# ### distribution of chol

# %%
sns.distplot(df['chol'])

# %% [markdown]
# * here the outliers are from 500 to 600

# %% [markdown]
# ### distribution of thalach

# %%
sns.distplot(df['thalach'])

# %% [markdown]
# * this is a left skewed data

# %% [markdown]
# ### distribution of oldpeak

# %%
sns.distplot(df['oldpeak'])

# %% [markdown]
# * if we clearly observe that the data is right skewed

# %% [markdown]
# ### so here we no need to worry about outliers since Random forest,KNN,Decision Tree,Naive Bayes Classifier are  not sensitive for outliers

# %% [markdown]
# ### Relationship between continuous variables

# %%
sns.pairplot(df[['age','chol','thalach','trestbps','oldpeak','target']],hue='target')
plt.savefig("25.png")

# %%
fig=plt.figure(figsize=(15,10))
corr=df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True)
plt.savefig("27.png")

# %% [markdown]
# * from the heat map we can conclude that there are no features which are highly correlated.
# * by using heat map we can't select best features.
